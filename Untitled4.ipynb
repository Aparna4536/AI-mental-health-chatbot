# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparna4536/AI-mental-health-chatbot/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Number Guessing game project

# %%
import random

def guess_the_number():
    # Generate random number between 1 and 100
    number = random.randint(1, 100)

    print("Welcome to Guess the Number Game!")
    print("Guess a number between 1 and 100\n")

    while True:
        try:
            # Take user input
            guess = int(input("Enter your guess: "))

            # Calculate difference
            difference = abs(guess - number)

            # Conditions
            if difference == 0:
                print("Correct! You guessed the number.")
                break
            elif difference <= 10:
                print("Hot")
            else:
                print("Cold")

        except ValueError:
            print("Invalid input! Please enter a number.")

# Run the game
guess_the_number()
# Out:
# Welcome to Guess the Number Game!
# Guess a number between 1 and 100
#
# Enter your guess: 50
# Cold
# Enter your guess: 30
# Hot
# Enter your guess: 35
# Hot
# Enter your guess: 23
# Cold
# Enter your guess: 36
# Correct! You guessed the number.
